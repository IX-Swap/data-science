# %%
import pandas as pd
import numpy as np
import os

# %%
print(os.getcwd())

wbtc_df = pd.read_csv(os.getcwd() + "\WBTC-USDT_01-10_31-10.csv", index_col=False)
# Out:
# I:\playground\monte_carlo_sim

# %%
wbtc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Txhash           5000 non-null   object
#  1   UnixTimestamp    5000 non-null   int64
#  2   DateTime         5000 non-null   object
#  3   From             5000 non-null   object
#  4   To               5000 non-null   object
#  5   Value            5000 non-null   object
#  6   ContractAddress  5000 non-null   object
#  7   TokenName        5000 non-null   object
#  8   TokenSymbol      5000 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 351.7+ KB

# %%
wbtc_df.tail(10)
# Out:
#                                                  Txhash  UnixTimestamp  \
# 4990  0xe4aa44b11fdbedf4606d37b76e8733cb0850c118d576...     1631480075
# 4991  0xe4aa44b11fdbedf4606d37b76e8733cb0850c118d576...     1631480075
# 4992  0x37e364174382854268efedaed0245547276f27f07200...     1631480075
# 4993  0x37e364174382854268efedaed0245547276f27f07200...     1631480075
# 4994  0xcb722347f2a370b6252aff73e0a54a59c38100d5fe0b...     1631480299
# 4995  0xcb722347f2a370b6252aff73e0a54a59c38100d5fe0b...     1631480299
# 4996  0xf0796225f1b2442e442b40bec60a8809478ff97acf24...     1631480398
# 4997  0xf0796225f1b2442e442b40bec60a8809478ff97acf24...     1631480398
# 4998  0xd4be6de779f2c8b71c563119991d7b1fe2987a2b9661...     1631480488
# 4999  0xd4be6de779f2c8b71c563119991d7b1fe2987a2b9661...     1631480488
#
#                  DateTime                                        From  \
# 4990  2021-09-12 20:54:35  0xcbcdf9626bc03e24f779434178a73a0b4bad62ed
# 4991  2021-09-12 20:54:35  0x0000006daea1723962647b7e189d311d757fb793
# 4992  2021-09-12 20:54:35  0xcbcdf9626bc03e24f779434178a73a0b4bad62ed
# 4993  2021-09-12 20:54:35  0x0000006daea1723962647b7e189d311d757fb793
# 4994  2021-09-12 20:58:19  0xcbcdf9626bc03e24f779434178a73a0b4bad62ed
# 4995  2021-09-12 20:58:19  0x0000006daea1723962647b7e189d311d757fb793
# 4996  2021-09-12 20:59:58  0xcbcdf9626bc03e24f779434178a73a0b4bad62ed
# 4997  2021-09-12 20:59:58  0x0000006daea1723962647b7e189d311d757fb793
# 4998  2021-09-12 21:01:28  0xcbcdf9626bc03e24f779434178a73a0b4bad62ed
# 4999  2021-09-12 21:01:28  0x27239549dd40e1d60f5b80b0c4196923745b1fd2
#
#                                               To       Value  \
# 4990  0x0000006daea1723962647b7e189d311d757fb793  5.54269751
# 4991  0xcbcdf9626bc03e24f779434178a73a0b4bad62ed     74.9978
# 4992  0x0000006daea1723962647b7e189d311d757fb793   5.5386518
# 4993  0xcbcdf9626bc03e24f779434178a73a0b4bad62ed     74.9978
# 4994  0x0000006daea1723962647b7e189d311d757fb793  5.56132999
# 4995  0xcbcdf9626bc03e24f779434178a73a0b4bad62ed       75.36
# 4996  0x0000006daea1723962647b7e189d311d757fb793  5.54931487
# 4997  0xcbcdf9626bc03e24f779434178a73a0b4bad62ed     75.2523
# 4998  0x27239549dd40e1d60f5b80b0c4196923745b1fd2   3.2874728
# 4999  0xcbcdf9626bc03e24f779434178a73a0b4bad62ed    44.60625
#
#                                  ContractAddress      TokenName TokenSymbol
# 4990  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599    Wrapped BTC        WBTC
# 4991  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  Wrapped Ether        WETH
# 4992  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599    Wrapped BTC        WBTC
# 4993  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  Wrapped Ether        WETH
# 4994  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599    Wrapped BTC        WBTC
# 4995  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  Wrapped Ether        WETH
# 4996  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599    Wrapped BTC        WBTC
# 4997  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  Wrapped Ether        WETH
# 4998  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599    Wrapped BTC        WBTC
# 4999  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  Wrapped Ether        WETH

# %%
print(wbtc_df['From'].mode()[0])
print(wbtc_df['To'].mode()[0])
# Out:
# 0x99ac8ca7087fa4a2a1fb6357269965a2014abc35
# 0x99ac8ca7087fa4a2a1fb6357269965a2014abc35

# %%
class TransactionHistory:
    def __init__(self, transactions_df: pd.DataFrame):
        self.user_in_swap_df = None
        self.user_out_swap_df = None
        self.pool_address = transactions_df['From'].mode()[0]
        
    
    def classify_history(self, transactions_df: pd.DataFrame):
        group_df = transactions_df.groupby('Txhash').agg({
            'From': self.__contract_address_count__,
            'To': self.__contract_address_count__
        })
        
        swap_txhash_list = group_df[(group_df['From'] == 1) & (group_df['To'] == 1)].index.values
        self.user_in_swap_df = transactions_df[(transactions_df['Txhash'].isin(swap_txhash_list)) & (transactions_df['To'] == self.pool_address)]
        self.user_out_swap_df = transactions_df[(transactions_df['Txhash'].isin(swap_txhash_list)) & (transactions_df['From'] == self.pool_address)]
        
        
    def __contract_address_count__(self, s):
        return (s == self.pool_address).sum()

# %%
th = TransactionHistory(wbtc_df)
th.classify_history(wbtc_df)

# %%
th.
