# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

sys.path.insert(0, "C:/workspace/data-science//libs")
from sushiswap_extractor import get_pool_reserves_history, get_pool_history, list_to_transaction_dictionary, list_to_reserves_dictionary,\
                                pool_reserves_to_df, pool_history_to_df, get_pool_mints, get_pool_burns, list_to_mints_dictionary,\
                                pool_mints_to_df, pool_burns_to_df, filter_swaps

# %% [markdown]
# # DOG/WETH

# %%
dog_weth_history = get_pool_history(contract_id='0xc96f20099d96b37d7ede66ff9e4de59b9b1065b1')
all_dog_weth_history, other_dog_weth_history = filter_swaps(dog_weth_history)
dog_weth_df = pool_history_to_df(all_dog_weth_history)
dog_weth_df
# Out:
#   0%|          | 21/20000 [01:52<29:36:52,  5.34s/it]
# list index out of range
#       token_in token_out     amount_in    amount_out    amount_usd  \
# 0         WETH       DOG  1.440000e+00  4.073501e+05   5432.695485
# 1         WETH       DOG  2.000000e+00  5.664152e+05   7545.410395
# 2         WETH       DOG  1.320265e+01  3.616879e+06  49819.709025
# 3         WETH       DOG  1.000000e+00  2.796039e+05   3773.461477
# 4         WETH       DOG  1.000000e+00  2.800503e+05   3773.461477
# ...        ...       ...           ...           ...           ...
# 20559      DOG      WETH  7.863680e+04  9.030943e-02    264.482785
# 20560     WETH       DOG  2.000000e-01  1.730851e+05    580.139400
# 20561      DOG      WETH  2.099181e+07  2.347754e+01  67689.366261
# 20562     WETH       DOG  2.000000e+00  1.821821e+06   5766.198080
# 20563     WETH       DOG  8.000000e-01  7.263740e+05   2321.630716
#
#                 timestamp                                      sender  \
# ...

# %%
dog_weth_reserves = get_pool_reserves_history(contract_id='0xc96f20099d96b37d7ede66ff9e4de59b9b1065b1', range_limit=20)
dog_weth_reserves_df = pool_reserves_to_df(dog_weth_reserves)
dog_weth_reserves_df
# Out:
#   5%|▌         | 1/20 [00:00<00:13,  1.36it/s]
# list index out of range
#          reserve0     reserve1    reserveUSD  dailyVolumeToken0  \
# 0    6.356670e+08  4052.465452  3.074421e+07       2.406400e+09
# 1    5.359100e+08  4952.562595  3.887745e+07       2.549169e+09
# 2    6.253961e+08  4153.561977  3.226891e+07       1.135736e+09
# 3    6.292579e+08  4169.444831  3.297632e+07       4.005114e+08
# 4    7.146884e+08  3693.187451  2.903818e+07       8.375415e+08
# ..            ...          ...           ...                ...
# 179  7.250931e+08   940.449079  5.265533e+06       5.497524e+07
# 180  7.408347e+08   920.558983  5.450159e+06       2.498821e+07
# 181  7.696415e+08   886.270907  5.196524e+06       4.815814e+07
# 182  8.019439e+08   850.714667  4.806656e+06       4.457938e+07
# 183  8.023535e+08   850.281685  4.670785e+06       4.303414e+05
#
#      dailyVolumeToken1       date     volumeUSD
# 0         11710.097827 2021-09-02  4.437262e+07
# ...

# %%
dog_weth_mints = get_pool_mints(contract_id='0xc96f20099d96b37d7ede66ff9e4de59b9b1065b1', range_limit=10)
dog_weth_mints_df = pool_mints_to_df(dog_weth_mints)
dog_weth_mints_df
# Out:
#  10%|█         | 1/10 [00:00<00:06,  1.45it/s]
# list index out of range
#          amount0      amount1     amountUSD     liquidity           timestamp
# 0   8.484848e+08  2985.000000  1.126153e+07  1.591454e+06 2021-09-02 18:58:39
# 1   2.553574e+06    12.000000  9.065086e+04  1.491186e+02 2021-09-02 19:13:57
# 2   1.131458e+05     0.573058  4.327569e+03  7.955130e+01 2021-09-02 19:23:54
# 3   2.839083e+06    13.204380  1.008869e+05  7.051724e+02 2021-09-02 21:22:37
# 4   1.131999e+06     7.000000  5.309290e+04  2.409574e+02 2021-09-03 00:16:35
# ..           ...          ...           ...           ...                 ...
# 71  9.115207e+05     2.993934  2.433856e+04  6.675950e+01 2021-11-26 16:08:04
# 72  2.000000e+06     5.070682  4.350462e+04  2.083994e+02 2021-12-07 23:30:36
# 73  1.584900e+03     0.003875  3.304444e+01  2.847136e+00 2021-12-09 14:40:52
# 74  1.487774e+06     2.900000  2.347669e+04  4.169195e+00 2021-12-12 01:52:15
# ...

# %%
dog_weth_burns = get_pool_burns(contract_id='0xc96f20099d96b37d7ede66ff9e4de59b9b1065b1', range_limit=10)
dog_weth_burns_df = pool_burns_to_df(dog_weth_burns)
dog_weth_burns_df
# Out:
#  10%|█         | 1/10 [00:01<00:09,  1.07s/it]
# list index out of range
#          amount0    amount1      amountUSD    liquidity           timestamp
# 0   2.840204e+06  13.199229  100822.851272  6104.874434 2021-09-02 21:27:09
# 1   5.464182e+04   0.298246    2271.188696   127.226311 2021-09-02 22:48:02
# 2   1.183244e+05   1.012607    8038.093283   343.315572 2021-09-03 15:45:31
# 3   1.173057e+05   0.869720    6785.388462   316.201449 2021-09-04 11:26:55
# 4   1.303380e+06   8.239186   63630.675035  3240.384845 2021-09-04 17:41:54
# ..           ...        ...            ...          ...                 ...
# 62  2.839049e+06   3.502393   17934.711539  2989.693744 2022-01-29 01:19:38
# 63  1.635610e+05   0.203120    1035.188572   172.806620 2022-01-31 13:34:11
# 64  2.408158e+06   4.048885   24163.731683  2959.197273 2022-02-05 00:56:01
# 65  1.841302e+05   0.284756    1666.116095   216.849545 2022-02-14 18:51:33
# ...

# %% [markdown]
# ## Writing to/reading from pickle files

# %%
# dog_weth_df.to_pickle(os.getcwd() + "\\pkl_stories\\dog_weth_swaps.pkl")
dog_weth_reserves_df.to_pickle(os.getcwd() + "\\pkl_stories\\dog_weth_reserves.pkl")
# dog_weth_mints_df.to_pickle(os.getcwd() + "\\pkl_stories\\dog_weth_mints.pkl")
# dog_weth_burns_df.to_pickle(os.getcwd() + "\\pkl_stories\\dog_weth_burns.pkl")

# %%
dog_weth_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\dog_weth_swaps.pkl")
# dog_weth_reserves_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\dog_weth_reserves.pkl")
dog_weth_mints_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\dog_weth_mints.pkl")
dog_weth_burns_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\dog_weth_burns.pkl")

# %% [markdown]
# # WETH/NFD

# %%
nfd_weth_history = get_pool_history(contract_id='0xeefa3b448768dd561af4f743c9e925987a1f8d09')
all_nfd_weth_history, other_nfd_weth_history = filter_swaps(nfd_weth_history)
nfd_weth_df = pool_history_to_df(all_nfd_weth_history)
nfd_weth_df
# Out:
#   0%|          | 20/20000 [01:01<17:00:17,  3.06s/it]
# list index out of range
#       token_in token_out     amount_in    amount_out    amount_usd  \
# 0         WETH       NFD  1.500000e-01  2.973214e+07    460.338077
# 1         WETH       NFD  1.000000e-01  1.962541e+07    306.925436
# 2         WETH       NFD  1.000000e+00  1.880516e+08   3069.149693
# 3         WETH       NFD  1.370000e+00  2.355591e+08   4204.735079
# 4         WETH       NFD  3.945978e+00  5.644259e+08  12110.834748
# ...        ...       ...           ...           ...           ...
# 19557     WETH       NFD  9.912500e-04  2.296285e+04      2.903742
# 19558      NFD      WETH  2.575724e+07  1.101596e+00   3252.403370
# 19559      NFD      WETH  3.000000e+07  1.273969e+00   3764.468791
# 19560      NFD      WETH  1.043762e+08  4.357824e+00  12640.757980
# 19561      NFD      WETH  7.863725e+05  3.239869e-02     94.748599
#
#                 timestamp                                      sender  \
# ...

# %%
nfd_weth_reserves = get_pool_reserves_history(contract_id='0xeefa3b448768dd561af4f743c9e925987a1f8d09', range_limit=20)
nfd_weth_reserves_df = pool_reserves_to_df(nfd_weth_reserves)
nfd_weth_reserves_df
# Out:
#   5%|▌         | 1/20 [00:00<00:14,  1.28it/s]
# list index out of range
#        reserve0      reserve1    reserveUSD  dailyVolumeToken0  \
# 0    159.644589  6.067606e+09  1.012567e+06         771.187922
# 1    222.096042  5.617182e+09  1.455379e+06        1188.345573
# 2    316.784630  4.076239e+09  2.049633e+06        1291.257563
# 3    585.635572  2.495918e+09  3.801477e+06       12909.239846
# 4    513.546390  2.916227e+09  3.415693e+06        3264.012821
# ..          ...           ...           ...                ...
# 193  343.976121  7.626475e+09  1.931548e+06           2.219421
# 194  345.654861  7.589626e+09  2.090057e+06           2.901866
# 195  336.044236  7.808050e+09  1.968798e+06          19.914160
# 196  329.069955  7.974033e+09  1.857013e+06           6.974281
# 197  327.031367  8.023891e+09  1.786474e+06           2.050240
#
#      dailyVolumeToken1       date     volumeUSD
# 0         2.708090e+10 2021-08-19  2.388929e+06
# ...

# %%
nfd_weth_mints = get_pool_mints(contract_id='0xeefa3b448768dd561af4f743c9e925987a1f8d09', range_limit=10)
nfd_weth_mints_df = pool_mints_to_df(nfd_weth_mints)
nfd_weth_mints_df
# Out:
#  10%|█         | 1/10 [00:00<00:05,  1.53it/s]
# list index out of range
#        amount0       amount1      amountUSD      liquidity           timestamp
# 0    25.000000  5.000000e+09   76667.032765  353553.390593 2021-08-19 15:47:00
# 1    77.939140  5.000000e+09  492106.279383     730.475939 2021-08-19 21:08:05
# 2     0.350000  8.762175e+06    2257.539261     702.724780 2021-08-20 06:41:53
# 3   100.000000  1.015455e+10  650402.199250      19.578852 2021-08-20 20:02:44
# 4     0.081010  2.749563e+06     529.241386     575.866048 2021-08-20 20:43:16
# ..         ...           ...            ...            ...                 ...
# 62    2.590341  1.570025e+07   22160.521381     685.596649 2021-10-29 00:00:55
# 63    3.700190  2.796319e+07   32110.859775      85.559058 2021-10-29 05:22:24
# 64    0.150408  1.000000e+06    1294.390845      45.588516 2021-10-30 17:46:10
# 65   50.000000  6.857250e+08  307277.976204     712.440532 2022-02-09 03:20:28
# ...

# %%
nfd_weth_burns = get_pool_burns(contract_id='0xc96f20099d96b37d7ede66ff9e4de59b9b1065b1', range_limit=10)
nfd_weth_burns_df = pool_burns_to_df(nfd_weth_burns)
nfd_weth_burns_df
# Out:
#  10%|█         | 1/10 [00:00<00:05,  1.74it/s]
# list index out of range
#          amount0    amount1      amountUSD    liquidity           timestamp
# 0   2.840204e+06  13.199229  100822.851272  6104.874434 2021-09-02 21:27:09
# 1   5.464182e+04   0.298246    2271.188696   127.226311 2021-09-02 22:48:02
# 2   1.183244e+05   1.012607    8038.093283   343.315572 2021-09-03 15:45:31
# 3   1.173057e+05   0.869720    6785.388462   316.201449 2021-09-04 11:26:55
# 4   1.303380e+06   8.239186   63630.675035  3240.384845 2021-09-04 17:41:54
# ..           ...        ...            ...          ...                 ...
# 62  2.839049e+06   3.502393   17934.711539  2989.693744 2022-01-29 01:19:38
# 63  1.635610e+05   0.203120    1035.188572   172.806620 2022-01-31 13:34:11
# 64  2.408158e+06   4.048885   24163.731683  2959.197273 2022-02-05 00:56:01
# 65  1.841302e+05   0.284756    1666.116095   216.849545 2022-02-14 18:51:33
# ...

# %% [markdown]
# ## Writing to/reading from pickle files

# %%
# nfd_weth_df.to_pickle(os.getcwd() + "\\pkl_stories\\nfd_weth_swaps.pkl")
nfd_weth_reserves_df.to_pickle(os.getcwd() + "\\pkl_stories\\nfd_weth_reserves.pkl")
# nfd_weth_mints_df.to_pickle(os.getcwd() + "\\pkl_stories\\nfd_weth_mints.pkl")
# nfd_weth_burns_df.to_pickle(os.getcwd() + "\\pkl_stories\\nfd_weth_burns.pkl")

# %%
nfd_weth_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\nfd_weth_swaps.pkl")
# nfd_weth_reserves_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\nfd_weth_reserves.pkl")
nfd_weth_mints_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\nfd_weth_mints.pkl")
nfd_weth_burns_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\nfd_weth_burns.pkl")

# %% [markdown]
# # WETH/LADY

# %%
lady_weth_history = get_pool_history(contract_id='0xe56db0b80bed4a9151691046e52acbb51f61753f')
all_lady_weth_history, other_lady_weth_history = filter_swaps(lady_weth_history)
lady_weth_df = pool_history_to_df(all_lady_weth_history)
lady_weth_df
# Out:
#   0%|          | 2/20000 [00:04<13:08:23,  2.37s/it]
# list index out of range
#      token_in token_out     amount_in    amount_out    amount_usd  \
# 0        LADY      WETH  5.525459e+07  7.096623e+00  22705.405473
# 1        WETH      LADY  6.793286e+00  5.525459e+07  21734.889187
# 2        WETH      LADY  1.000000e+00  6.456981e+06   3199.466246
# 3        WETH      LADY  1.500000e+00  9.125166e+06   4799.235171
# 4        WETH      LADY  7.002146e+00  5.438918e+07  22403.295870
# ...       ...       ...           ...           ...           ...
# 1753     LADY      WETH  1.002433e+05  1.855773e-02     51.383972
# 1754     LADY      WETH  5.323090e+04  9.847697e-03     27.225538
# 1755     LADY      WETH  5.362185e+04  9.915273e-03     27.436575
# 1756     LADY      WETH  5.782396e+05  1.066214e-01    312.795031
# 1757     LADY      WETH  2.767147e+06  5.027071e-01   1517.320210
#
#                timestamp                                      sender  \
# ...

# %%
lady_weth_reserves = get_pool_reserves_history(contract_id='0xe56db0b80bed4a9151691046e52acbb51f61753f', range_limit=20)
lady_weth_reserves_df = pool_reserves_to_df(lady_weth_reserves)
lady_weth_reserves_df
# Out:
#   5%|▌         | 1/20 [00:00<00:15,  1.22it/s]
# list index out of range
#      reserve0      reserve1     reserveUSD  dailyVolumeToken0  \
# 0   66.053507  1.385065e+08  426086.116986         293.119504
# 1   60.696224  1.510241e+08  402683.115208          43.454539
# 2   55.384623  1.656188e+08  375282.554260          13.177481
# 3   53.136929  1.726669e+08  388285.353267           4.531695
# 4   48.389452  1.896666e+08  366452.985937           5.307677
# ..        ...           ...            ...                ...
# 76  41.490334  2.220307e+08  237848.182011           0.052592
# 77  41.377036  2.226405e+08  224550.458655           0.113298
# 78  41.368200  2.226882e+08  230928.208223           0.008836
# 79  41.329879  2.228953e+08  228728.000087           0.038321
# 80  40.720551  2.262407e+08  245813.595243           0.609328
#
#     dailyVolumeToken1       date      volumeUSD
# 0        1.057889e+09 2021-08-29  937242.835036
# 1        8.905327e+07 2021-08-30  138572.137197
# ...

# %%
lady_weth_mints = get_pool_mints(contract_id='0xe56db0b80bed4a9151691046e52acbb51f61753f', range_limit=10)
lady_weth_mints_df = pool_mints_to_df(lady_weth_mints)
lady_weth_mints_df
# Out:
#  10%|█         | 1/10 [00:00<00:06,  1.31it/s]
# list index out of range
#    amount0      amount1    amountUSD     liquidity           timestamp
# 0     30.0  300000000.0  95985.25606  94868.329805 2021-08-29 11:24:27

# %%
lady_weth_burns = get_pool_burns(contract_id='0xe56db0b80bed4a9151691046e52acbb51f61753f', range_limit=10)
lady_weth_burns_df = pool_burns_to_df(lady_weth_burns)
lady_weth_burns_df
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# list index out of range
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-70b0e6fac359> in <module>
#       1 lady_weth_burns = get_pool_burns(contract_id='0xe56db0b80bed4a9151691046e52acbb51f61753f', range_limit=10)
# ----> 2 lady_weth_burns_df = pool_burns_to_df(lady_weth_burns)
#       3 lady_weth_burns_df
#
# C:/workspace/data-science//libs\sushiswap_extractor.py in pool_burns_to_df(burns_list)
#     360     all_burns_df = pd.DataFrame([list_to_mints_dictionary(burn) for burn in burns_list])
#     361
# --> 362     all_burns_df['amount0'] = all_burns_df.amount0.astype('float')
#     363     all_burns_df['amount1'] = all_burns_df.amount1.astype('float')
#     364     all_burns_df['amountUSD'] = all_burns_df.amountUSD.astype('float')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
# ...

# %% [markdown]
# ## Writing to/reading from pickle files

# %%
# lady_weth_df.to_pickle(os.getcwd() + "\\pkl_stories\\lady_weth_swaps.pkl")
lady_weth_reserves_df.to_pickle(os.getcwd() + "\\pkl_stories\\lady_weth_reserves.pkl")
# lady_weth_mints_df.to_pickle(os.getcwd() + "\\pkl_stories\\lady_weth_mints.pkl")
# lady_weth_burns_df.to_pickle(os.getcwd() + "\\pkl_stories\\lady_weth_burns.pkl")

# %%
lady_weth_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\lady_weth_swaps.pkl")
# lady_weth_reserves_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\lady_weth_reserves.pkl")
lady_weth_mints_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\lady_weth_mints.pkl")
# lady_weth_burns_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\lady_weth_burns.pkl")

# %% [markdown]
# # CAT/WETH

# %%
cat_weth_history = get_pool_history(contract_id='0xb18b3f388517cf06720693b90c55b8650d4d4e0b')
all_cat_weth_history, other_cat_weth_history = filter_swaps(cat_weth_history)
cat_weth_df = pool_history_to_df(all_cat_weth_history)
cat_weth_df
# Out:
#   0%|          | 1/20000 [00:00<3:49:24,  1.45it/s]
# list index out of range
#    token_in token_out     amount_in    amount_out    amount_usd  \
# 0      WETH       CAT      1.000000   4748.297376   2906.260617
# 1      WETH       CAT      0.040000    180.544656    116.381874
# 2      WETH       CAT      0.797231   3460.814036   2319.571937
# 3      WETH       CAT      0.056858    237.194333    165.429031
# 4      WETH       CAT      1.000000   3979.672215   2909.511947
# 5      WETH       CAT      0.100000    378.934057    290.953798
# 6      WETH       CAT      0.100000    375.657283    290.948909
# 7      WETH       CAT      0.107439    400.000219    312.591011
# 8      WETH       CAT      0.058168    215.022979    169.224936
# 9       CAT      WETH   3979.672215      1.025521   2983.270469
# 10      CAT      WETH   3460.814036      0.820912   2392.081772
# 11      CAT      WETH    237.194333      0.054043    157.489496
# ...

# %%
cat_weth_reserves = get_pool_reserves_history(contract_id='0xb18b3f388517cf06720693b90c55b8650d4d4e0b', range_limit=20)
cat_weth_reserves_df = pool_reserves_to_df(cat_weth_reserves)
cat_weth_reserves_df
# Out:
#   5%|▌         | 1/20 [00:00<00:15,  1.24it/s]
# list index out of range
#          reserve0   reserve1     reserveUSD  dailyVolumeToken0  \
# 0    93428.972747  21.422243  125852.529744       22684.256535
# 1    80627.884114  24.864088  154221.237470       47481.148067
# 2    81655.046137  24.552245  151061.176647        1027.162023
# 3    91655.046137  21.880641  122588.081799       10000.000000
# 4    91442.276619  21.931706  131905.432395         212.769518
# 5    91193.540949  21.991706  159088.031856         248.735669
# 6    90781.978374  22.091706  159836.876205         411.562575
# 7    90333.535022  22.201706  159565.128155         448.443352
# 8    90781.978374  22.092362  153555.488051         448.443352
# 9    91099.667706  22.015550  157943.807272         317.689332
# 10   87152.848781  23.015550  166757.971007        3946.818925
# 11   81835.366086  24.515550  187291.915827        5317.482695
# 12   82050.389065  24.451496  200925.170540         215.022979
# ...

# %%
cat_weth_mints = get_pool_mints(contract_id='0xb18b3f388517cf06720693b90c55b8650d4d4e0b', range_limit=10)
cat_weth_mints_df = pool_mints_to_df(cat_weth_mints)
cat_weth_mints_df
# Out:
#  10%|█         | 1/10 [00:00<00:03,  2.30it/s]
# list index out of range
#     amount0  amount1     amountUSD    liquidity           timestamp
# 0  100000.0     20.0  58074.629878  1414.213562 2021-09-25 21:24:05

# %%
cat_weth_burns = get_pool_burns(contract_id='0xb18b3f388517cf06720693b90c55b8650d4d4e0b', range_limit=10)
cat_weth_burns_df = pool_burns_to_df(cat_weth_burns)
cat_weth_burns_df
# Out:
#  10%|█         | 1/10 [00:00<00:03,  2.34it/s]
# list index out of range
#         amount0   amount1      amountUSD    liquidity           timestamp
# 0  103841.45046  19.32268  102421.833458  1414.213562 2022-02-03 07:01:18

# %% [markdown]
# ## Writing to/Reading from pickle files

# %%
# cat_weth_df.to_pickle(os.getcwd() + "\\pkl_stories\\cat_weth_swaps.pkl")
cat_weth_reserves_df.to_pickle(os.getcwd() + "\\pkl_stories\\cat_weth_reserves.pkl")
# cat_weth_mints_df.to_pickle(os.getcwd() + "\\pkl_stories\\cat_weth_mints.pkl")
# cat_weth_burns_df.to_pickle(os.getcwd() + "\\pkl_stories\\cat_weth_burns.pkl")

# %%
cat_weth_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\cat_weth_swaps.pkl")
# cat_weth_reserves_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\cat_weth_reserves.pkl")
cat_weth_mints_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\cat_weth_mints.pkl")
cat_weth_burns_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\cat_weth_burns.pkl")

# %% [markdown]
# # $TIARA/WETH

# %%
tiara_weth_history = get_pool_history(contract_id='0x0269197835253efc311ffe7d0aa3fbdbc1760443')
all_tiara_weth_history, other_tiara_weth_history = filter_swaps(tiara_weth_history)
tiara_weth_df = pool_history_to_df(all_tiara_weth_history)
tiara_weth_df
# Out:
#   0%|          | 1/20000 [00:01<7:11:11,  1.29s/it]
# list index out of range
#     token_in token_out   amount_in  amount_out   amount_usd  \
# 0       WETH    $TIARA    0.150000  139.145403   467.867088
# 1     $TIARA      WETH  139.984047    0.150000   467.865376
# 2     $TIARA      WETH  139.145403    0.129679   404.454167
# 3       WETH    $TIARA    1.626809  983.947909  5065.407271
# 4       WETH    $TIARA    0.012299   13.938633    38.295396
# ..       ...       ...         ...         ...          ...
# 223     WETH    $TIARA    0.031000   42.253973    87.219659
# 224   $TIARA      WETH  300.280383    0.209510   546.378444
# 225     WETH    $TIARA    0.400000  545.131287  1039.214371
# 226   $TIARA      WETH   42.253973    0.033679   100.904520
# 227     WETH    $TIARA    0.150000  182.213755   439.057604
#
#               timestamp                                      sender  \
# 0   2021-08-10 03:42:19  0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f
# ...

# %%
tiara_weth_reserves = get_pool_reserves_history(contract_id='0x0269197835253efc311ffe7d0aa3fbdbc1760443', range_limit=20)
tiara_weth_reserves_df = pool_reserves_to_df(tiara_weth_reserves)
tiara_weth_reserves_df
# Out:
#   5%|▌         | 1/20 [00:00<00:18,  1.06it/s]
# list index out of range
#        reserve0  reserve1    reserveUSD  dailyVolumeToken0  dailyVolumeToken1  \
# 0   1967.782721  2.100429   6573.720495       22736.760816          37.552147
# 1     10.286852  0.003576     10.733163        3051.829257           4.132937
# 2      1.564302  0.023576     76.690037           8.722550           0.020000
# 3      0.542384  0.068205    214.897748           1.221918           0.075371
# 4      0.305629  0.121205    386.071696           0.236755           0.053000
# ..          ...       ...           ...                ...                ...
# 60  5641.043499  4.157186  23392.793865          42.253973           0.031000
# 61  5396.192594  4.347676  22590.836032         845.411669           0.609510
# 62  5438.446567  4.313997  25850.286055          42.253973           0.033679
# 63  5256.232812  4.463997  26132.691914         182.213755           0.150000
# ...

# %%
tiara_weth_mints = get_pool_mints(contract_id='0x0269197835253efc311ffe7d0aa3fbdbc1760443', range_limit=10)
tiara_weth_mints_df = pool_mints_to_df(tiara_weth_mints)
tiara_weth_mints_df
# Out:
#  10%|█         | 1/10 [00:00<00:04,  2.15it/s]
# list index out of range
#        amount0   amount1     amountUSD  liquidity           timestamp
# 0  2000.000000  2.000000   6243.881846  63.245553 2021-08-10 03:35:13
# 1    39.088231  0.300000   1138.458261   0.001600 2021-09-02 00:43:52
# 2  5000.000000  4.387672  18491.413883   0.003633 2021-10-25 23:19:12

# %%
tiara_weth_burns = get_pool_burns(contract_id='0x0269197835253efc311ffe7d0aa3fbdbc1760443', range_limit=10)
tiara_weth_burns_df = pool_burns_to_df(tiara_weth_burns)
tiara_weth_burns_df
# Out:
#  10%|█         | 1/10 [00:00<00:04,  1.93it/s]
# list index out of range
#       amount0   amount1     amountUSD  liquidity           timestamp
# 0  950.479833  4.336116  13972.141243  63.245553 2021-08-12 04:11:32

# %% [markdown]
# ## Writing to/reading from pickle files

# %%
# tiara_weth_df.to_pickle(os.getcwd() + "\\pkl_stories\\tiara_weth_swaps.pkl")
tiara_weth_reserves_df.to_pickle(os.getcwd() + "\\pkl_stories\\tiara_weth_reserves.pkl")
# tiara_weth_mints_df.to_pickle(os.getcwd() + "\\pkl_stories\\tiara_weth_mints.pkl")
# tiara_weth_burns_df.to_pickle(os.getcwd() + "\\pkl_stories\\tiara_weth_burns.pkl")

# %%
tiara_weth_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\tiara_weth_swaps.pkl")
# tiara_weth_reserves_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\tiara_weth_reserves.pkl")
tiara_weth_mints_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\tiara_weth_mints.pkl")
tiara_weth_burns_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\tiara_weth_burns.pkl")

# %% [markdown]
# # ACAB/WETH

# %%
acab_weth_history = get_pool_history(contract_id='0x67e8e786e1b49ad6935df713866f0c10fef7da64')
all_acab_weth_history, other_acab_weth_history = filter_swaps(acab_weth_history)
acab_weth_df = pool_history_to_df(all_acab_weth_history)
acab_weth_df
# Out:
#   0%|          | 1/20000 [00:00<2:54:50,  1.91it/s]
# list index out of range
#    token_in token_out     amount_in    amount_out   amount_usd  \
# 0      WETH      ACAB  1.084038e+00  1.333034e+07  4981.179081
# 1      WETH      ACAB  2.167916e-01  2.115711e+06   996.260727
# 2      WETH      ACAB  1.062972e-02  1.000000e+05    48.881389
# 3      WETH      ACAB  1.900000e-02  1.779091e+05    87.385254
# 4      ACAB      WETH  2.115711e+06  2.175312e-01  1015.455996
# 5      ACAB      WETH  1.773775e+05  1.755835e-02    81.510610
# 6      ACAB      WETH  1.333034e+07  1.082156e+00  5125.579384
# 7      WETH      ACAB  1.000000e-01  1.460513e+06   468.253017
# 8      WETH      ACAB  2.000000e-02  2.852774e+05    80.791068
# 9      WETH      ACAB  8.200000e-01  1.005016e+07  3587.052440
# 10     WETH      ACAB  2.100000e-01  2.143903e+06   927.815725
# 11     WETH      ACAB  8.652945e-02  8.415058e+05   361.127212
# 12     ACAB      WETH  8.415058e+05  8.601819e-02   348.632926
# ...

# %%
acab_weth_reserves = get_pool_reserves_history(contract_id='0x67e8e786e1b49ad6935df713866f0c10fef7da64', range_limit=20)
acab_weth_reserves_df = pool_reserves_to_df(acab_weth_reserves)
acab_weth_reserves_df
# Out:
#   5%|▌         | 1/20 [00:00<00:09,  1.93it/s]
# list index out of range
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-1f75157be426> in <module>
#       1 acab_weth_reserves = get_pool_reserves_history(contract_id='0x67e8e786e1b49ad6935df713866f0c10fef7da64', range_limit=20)
# ----> 2 acab_weth_reserves_df = pool_reserves_to_df(acab_weth_reserves)
#       3 acab_weth_reserves_df
#
# C:/workspace/data-science//libs\sushiswap_extractor.py in pool_reserves_to_df(reserves_list)
#     312     """
#     313     # transform list of dictionaries into df
# --> 314     daily_data_df = pd.DataFrame([list_to_reserves_dictionary(x) for x in reserves_list])
#     315
#     316     daily_data_df['reserve0'] = daily_data_df['reserve0'].astype('float')
#
# C:/workspace/data-science//libs\sushiswap_extractor.py in <listcomp>(.0)
#     312     """
# ...

# %%
acab_weth_mints = get_pool_mints(contract_id='0x67e8e786e1b49ad6935df713866f0c10fef7da64', range_limit=10)
acab_weth_mints_df = pool_mints_to_df(acab_weth_mints)
acab_weth_mints_df
# Out:
#  10%|█         | 1/10 [00:00<00:03,  2.28it/s]
# list index out of range
#    amount0     amount1    amountUSD     liquidity           timestamp
# 0      5.0  75000000.0  22986.34757  19364.916731 2021-11-30 18:12:21

# %%
acab_weth_burns = get_pool_burns(contract_id='0x67e8e786e1b49ad6935df713866f0c10fef7da64', range_limit=10)
acab_weth_burns_df = pool_burns_to_df(acab_weth_burns)
acab_weth_burns_df
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# list index out of range
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-85477d821c8d> in <module>
#       1 acab_weth_burns = get_pool_burns(contract_id='0x67e8e786e1b49ad6935df713866f0c10fef7da64', range_limit=10)
# ----> 2 acab_weth_burns_df = pool_burns_to_df(acab_weth_burns)
#       3 acab_weth_burns_df
#
# C:/workspace/data-science//libs\sushiswap_extractor.py in pool_burns_to_df(burns_list)
#     360     all_burns_df = pd.DataFrame([list_to_mints_dictionary(burn) for burn in burns_list])
#     361
# --> 362     all_burns_df['amount0'] = all_burns_df.amount0.astype('float')
#     363     all_burns_df['amount1'] = all_burns_df.amount1.astype('float')
#     364     all_burns_df['amountUSD'] = all_burns_df.amountUSD.astype('float')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
# ...

# %% [markdown]
# # Writing to/reading from pickle files

# %%
acab_weth_df.to_pickle(os.getcwd() + "\\pkl_stories\\acab_weth_swaps.pkl")
# acab_weth_reserves_df.to_pickle(os.getcwd() + "\\pkl_stories\\acab_weth_reserves.pkl")
acab_weth_mints_df.to_pickle(os.getcwd() + "\\pkl_stories\\acab_weth_mints.pkl")
# acab_weth_burns_df.to_pickle(os.getcwd() + "\\pkl_stories\\acab_weth_burns.pkl")

# %%
acab_weth_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\acab_weth_swaps.pkl")
# acab_weth_reserves_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\acab_weth_reserves.pkl")
acab_weth_mints_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\acab_weth_mints.pkl")
# acab_weth_burns_df = pd.read_pickle(os.getcwd() + "\\pkl_stories\\acab_weth_burns.pkl")
