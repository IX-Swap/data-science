# %% [markdown]
# # imports and getting data from csv

# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
google_df = pd.read_csv(os.getcwd() + '\stress_test_sim\GOOG.csv')
microsoft_df = pd.read_csv(os.getcwd() + '\stress_test_sim\MSFT.csv')
apple_df = pd.read_csv(os.getcwd() + '\stress_test_sim\AAPL.csv')
amazon_df = pd.read_csv(os.getcwd() + '\stress_test_sim\AMZN.csv')
facebook_df = pd.read_csv(os.getcwd() + '\stress_test_sim\FB.csv')
netflix_df = pd.read_csv(os.getcwd() + '\stress_test_sim\\NFLX.csv')
tesla_df = pd.read_csv(os.getcwd() + '\stress_test_sim\TSLA.csv')

# %%
google_df
# Out:
#      Unnamed: 0               Insider      Type     Value          Date  \
# 0             0         PICHAI SUNDAR    Direct   8090303  Sep 15, 2021
# 1             1           BRIN SERGEY    Direct  40307198  Sep 09, 2021
# 2             2           BRIN SERGEY    Direct  40240838  Sep 08, 2021
# 3             3       HENNESSY JOHN L  Indirect    299520  Sep 07, 2021
# 4             4           BRIN SERGEY    Direct  40390311  Sep 07, 2021
# ..          ...                   ...       ...       ...           ...
# 145         145       HENNESSY JOHN L  Indirect     51806  Apr 06, 2020
# 146         146  O TOOLE AMIE THUENER    Direct     66994  Apr 02, 2020
# 147         147            MATHER ANN    Direct     38120  Apr 01, 2020
# 148         148          PORAT RUTH M    Direct         0  Mar 25, 2020
# 149         149         PICHAI SUNDAR    Direct         0  Mar 25, 2020
#
#      Shares        Price                                        Info
# 0      2825  2863.824071  Sale at price 2854.72 - 2878.99 per share.
# 1     13889  2902.095039  Sale at price 2889.83 - 2912.26 per share.
# 2     13889  2897.317157  Sale at price 2884.65 - 2911.14 per share.
# 3       103  2907.961165  Sale at price 2895.04 - 2914.46 per share.
# 4     13889  2908.079127  Sale at price 2892.87 - 2914.44 per share.
# ..      ...          ...                                         ...
# 145      45  1151.244444  Sale at price 1135.68 - 1173.04 per share.
# 146      61  1098.262295            Sale at price 1098.26 per share.
# 147      34  1121.176471            Sale at price 1121.18 per share.
# 148    1456     0.000000                                         NaN
# 149    6897     0.000000                                         NaN
#
# [150 rows x 8 columns]

# %% [markdown]
# # Plotting operations capitalization (in USD)
#
# From ```.csv```'s was taken information regarding shares insider transactions of 7 big companies: Google, Microsoft, Apple, Amazon, Facebook, Netflix, Tesla. Insider transactions cover transactions by people that have access to confidential inner-company information (in most of the cases, people are working inside the company).

# %%
plt.figure(figsize=(20, 20))

plt.subplot(3, 3, 1)
sns.histplot(data=google_df, x='Value', color='green').set_title(
    'Operations values for Google shares (in USD)'
    )
plt.subplot(3, 3, 2)
sns.histplot(data=microsoft_df, x='Value', color='blue').set_title(
    'Operations values for Microsoft shares (in USD)'
    )
plt.subplot(3, 3, 3)
sns.histplot(data=apple_df, x='Value', color='gray').set_title(
    'Operations values for Apple shares (in USD)'
    )
plt.subplot(3, 3, 4)
sns.histplot(data=amazon_df, x='Value', color='yellow').set_title(
    'Operations values for Amazon shares (in USD)'
    )
plt.subplot(3, 3, 5)
sns.histplot(data=facebook_df, x='Value', color='magenta').set_title(
    'Operations values for Facebook shares (in USD)'
    )
plt.subplot(3, 3, 6)
sns.histplot(data=netflix_df, x='Value', color='red').set_title(
    'Operations values for Netflix shares (in USD)'
    )
plt.subplot(3, 3, 7)
sns.histplot(data=tesla_df, x='Value', color='gray').set_title(
    'Operations values for Tesla shares (in USD)'
    )

plt.subplots_adjust(wspace=0.2, hspace=0.2)
plt.show()

# %%
google_df['datetime'] = pd.to_datetime(google_df['Date'], format="%b %d, %Y")
microsoft_df['datetime'] = pd.to_datetime(microsoft_df['Date'], format="%b %d, %Y")
apple_df['datetime'] = pd.to_datetime(apple_df['Date'], format="%b %d, %Y")
amazon_df['datetime'] = pd.to_datetime(amazon_df['Date'], format="%b %d, %Y")
facebook_df['datetime'] = pd.to_datetime(facebook_df['Date'], format="%b %d, %Y")
netflix_df['datetime'] = pd.to_datetime(netflix_df['Date'], format="%b %d, %Y")
tesla_df['datetime'] = pd.to_datetime(tesla_df['Date'], format="%b %d, %Y")

# %% [markdown]
# # Showing distribution of shares sales and their price
#
# This section demonstrates shares sales through time considering their price in USD and share price evolution through time.

# %%
plt.figure(figsize=(20, 50))

plt.subplot(7, 2, 1)
sns.lineplot(x='datetime', y='Value', data=google_df, color='green').set_title(
    "Google shares sales values through time (in USD)"
    )
plt.subplot(7, 2, 2)
sns.lineplot(x='datetime', y='Price', data=google_df, color="orange").set_title(
    "Google shares price through time (in USD)"
    )

plt.subplot(7, 2, 3)
sns.lineplot(x='datetime', y='Value', data=microsoft_df, color='blue').set_title(
    "Microsoft shares sales values through time (in USD)"
    )
plt.subplot(7, 2, 4)
sns.lineplot(x='datetime', y='Price', data=microsoft_df, color="orange").set_title(
    "Microsoft shares price through time (in USD)"
    )

plt.subplot(7, 2, 5)
sns.lineplot(x='datetime', y='Value', data=apple_df, color='gray').set_title(
    "Apple shares sales values through time (in USD)"
    )
plt.subplot(7, 2, 6)
sns.lineplot(x='datetime', y='Price', data=apple_df, color="orange").set_title(
    "Apple shares price through time (in USD)"
    )

plt.subplot(7, 2, 7)
sns.lineplot(x='datetime', y='Value', data=amazon_df, color='yellow').set_title(
    "Amazon shares sales values through time (in USD)"
    )
plt.subplot(7, 2, 8)
sns.lineplot(x='datetime', y='Price', data=amazon_df, color="orange").set_title(
    "Amazon shares price through time (in USD)"
    )

plt.subplot(7, 2, 9)
sns.lineplot(x='datetime', y='Value', data=facebook_df, color='magenta').set_title(
    "Facebook shares sales values through time (in USD)"
    )
plt.subplot(7, 2, 10)
sns.lineplot(x='datetime', y='Price', data=facebook_df, color="orange").set_title(
    "Facebook shares price through time (in USD)"
    )

plt.subplot(7, 2, 11)
sns.lineplot(x='datetime', y='Value', data=netflix_df, color='red').set_title(
    "Netflix shares sales values through time (in USD)"
    )
plt.subplot(7, 2, 12)
sns.lineplot(x='datetime', y='Price', data=netflix_df, color="orange").set_title(
    "Netflix shares price through time (in USD)"
    )

plt.subplot(7, 2, 13)
sns.lineplot(x='datetime', y='Value', data=tesla_df, color='gray').set_title(
    "Tesla shares sales values through time (in USD)"
    )
plt.subplot(7, 2, 14)
sns.lineplot(x='datetime', y='Price', data=tesla_df, color="orange").set_title(
    "Tesla shares price through time (in USD)"
    )

plt.show()

# %% [markdown]
# # Shares transactions
#
# This sections covers any shares movement and their amount, defining general trend of shares movement.

# %%
plt.figure(figsize=(20, 20))

plt.subplot(3, 3, 1)
sns.histplot(data=google_df, x='Shares', color='green').set_title(
    'Google shares transaction amount and their frequency'
    )
plt.subplot(3, 3, 2)
sns.histplot(data=microsoft_df, x='Shares', color='blue').set_title(
    'Microsoft shares transaction amount and their frequency'
    )
plt.subplot(3, 3, 3)
sns.histplot(data=apple_df, x='Shares', color='gray').set_title(
    'Apple shares transaction amount and their frequency'
    )
plt.subplot(3, 3, 4)
sns.histplot(data=amazon_df, x='Shares', color='yellow').set_title(
    'Amazon shares transaction amount and their frequency'
    )
plt.subplot(3, 3, 5)
sns.histplot(data=facebook_df, x='Shares', color='magenta').set_title(
    'Facebook shares transaction amount and their frequency'
    )
plt.subplot(3, 3, 6)
sns.histplot(data=netflix_df, x='Shares', color='red').set_title(
    'Netflix shares transaction amount and their frequency'
    )
plt.subplot(3, 3, 7)
sns.histplot(data=tesla_df, x='Shares', color='gray').set_title(
    'Tesla shares transaction amount and their frequency'
    )

plt.subplots_adjust(wspace=0.2, hspace=0.2)
plt.show()

# %% [markdown]
# # Shares transactions and price evolution
#
# This section is made to find possible connection between price and shares movement.

# %%
plt.figure(figsize=(20, 50))

plt.subplot(7, 2, 1)
sns.lineplot(x='datetime', y='Shares', data=google_df, color='green').set_title(
    "Google shares operations amount through time"
    )
plt.subplot(7, 2, 2)
sns.lineplot(x='datetime', y='Price', data=google_df, color="orange").set_title(
    "Google shares price through time (in USD)"
    )

plt.subplot(7, 2, 3)
sns.lineplot(x='datetime', y='Shares', data=microsoft_df, color='blue').set_title(
    "Microsoft shares operations amount through time"
    )
plt.subplot(7, 2, 4)
sns.lineplot(x='datetime', y='Price', data=microsoft_df, color="orange").set_title(
    "Microsoft shares price through time (in USD)"
    )

plt.subplot(7, 2, 5)
sns.lineplot(x='datetime', y='Shares', data=apple_df, color='gray').set_title(
    "Apple shares operations amount through time"
    )
plt.subplot(7, 2, 6)
sns.lineplot(x='datetime', y='Price', data=apple_df, color="orange").set_title(
    "Apple shares price through time (in USD)"
    )

plt.subplot(7, 2, 7)
sns.lineplot(x='datetime', y='Shares', data=amazon_df, color='yellow').set_title(
    "Amazon shares operations amount through time"
    )
plt.subplot(7, 2, 8)
sns.lineplot(x='datetime', y='Price', data=amazon_df, color="orange").set_title(
    "Amazon shares price through time (in USD)"
    )

plt.subplot(7, 2, 9)
sns.lineplot(x='datetime', y='Shares', data=facebook_df, color='magenta').set_title(
    "Facebook shares operations amount through time"
    )
plt.subplot(7, 2, 10)
sns.lineplot(x='datetime', y='Price', data=facebook_df, color="orange").set_title(
    "Facebook shares price through time (in USD)"
    )

plt.subplot(7, 2, 11)
sns.lineplot(x='datetime', y='Shares', data=netflix_df, color='red').set_title(
    "Netflix shares operations amount through time"
    )
plt.subplot(7, 2, 12)
sns.lineplot(x='datetime', y='Price', data=netflix_df, color="orange").set_title(
    "Netflix shares price through time (in USD)"
    )

plt.subplot(7, 2, 13)
sns.lineplot(x='datetime', y='Shares', data=tesla_df, color='gray').set_title(
    "Tesla shares operations amount through time"
    )
plt.subplot(7, 2, 14)
sns.lineplot(x='datetime', y='Price', data=tesla_df, color="orange").set_title(
    "Tesla shares price through time (in USD)"
    )

plt.show()

# %% [markdown]
# # Comparing Pareto, Cauchy distributions with shares distribution

# %%
from scipy.stats import halfcauchy

# generate half-cauchy (generates non-negative values) and pareto distributions 
cauchy = halfcauchy.rvs(size=1312, loc=0, scale=1700)
pareto = np.random.pareto(0.258, size=1700)

plt.figure(figsize=(10, 10))
plt.subplots_adjust(wspace=0.1, hspace=0.25)

plt.subplot(3, 1, 1)
sns.histplot(x=cauchy, color='green', binrange=[0, 300000], bins=100).set_title('Cauchy distribution')

plt.subplot(3, 1, 2)
sns.histplot(x=pareto, color='blue', binrange=[0, 300000], bins=100).set_title('Pareto distribution')

plt.subplot(3, 1, 3)
sns.histplot(data=apple_df, x='Shares', color='gray').set_title('Apple shares transaction amount and their frequency')

plt.show()

# %% [markdown]
# # Advanced analysis (trying to improve linecharts for better overviews)

# %%
def show_transactions_distribution_moving_average(
    df: pd.DataFrame, time_cycle: str, plot_name: str,
    target_column: str, x_size: int=15, y_size: int=9
    ) -> pd.DataFrame:
    
    # set new timestamp for making average calculations without touching original dataset
    # form column with second resolution
    df_time = df.copy()
    df_time.datetime = pd.to_datetime(df_time.datetime, unit='s')
    df_time = df_time[df_time[target_column] > 0]

    # set timestamp as index and then resample conform both resolutions (smaller_average 
    # step and bigger_average step)
    df_time.index = df_time.datetime
    df_avg_time = df_time.rolling(time_cycle).mean()
    df_time = df_avg_time

    # set size and set timeseries representation with automatic definition
    fig, ax = plt.subplots(figsize=(x_size, y_size))
    fig.autofmt_xdate()

    # plot information
    ax.plot_date(df_time.index, df_time[target_column], linestyle='solid', marker=None)

    # set labels
    ax.set_xlabel("Time")
    ax.set_ylabel("Average transaction value per " + time_cycle)

    # set title and legend
    fig.suptitle(plot_name)
    fig.legend()

    return df_time

# %% [markdown]
# ## Google
#
# Share price evolution shows clear rise of price over time. Considering that data contains drops related to gaps in insider trades, rise almost stable. Conform shares movement and capitalization graphs can be clearly seen that there was some strange rise in shares activity from the end of 2020 till October 2021 (before this moment there was a flat line of silence).
#
# Count distribution by capitalization value shows that distribution by overall shape looks like exponential one (Pareto or Cauchy), but deviations from exponential shape are strong, reducing similarity.

# %%
smooth_google_df = show_transactions_distribution_moving_average(
    google_df, time_cycle='30d', plot_name="Smoothed share price over time", target_column='Price',
    x_size=5, y_size=5
    )
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(5, 5))
ax = sns.lineplot(data=smooth_google_df, x='datetime', y='Value', color='red').set_title(
    'smoothed shares trades capitalization over time'
    )
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(data=smooth_google_df, x='datetime', y='Shares', color='green').set_title(
    'smoothed shares movements over time'
    )
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data=smooth_google_df, x='Value', color='orange', bins=50).set_title(
    'smoothed shares capitalizations count by value'
    )
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data=smooth_google_df, x='Shares', color='magenta', bins=50).set_title(
    'smoothed shares capitalizations count by value'
    )
plt.show()

# %% [markdown]
# ## Microsoft
#
# Microsoft share price evolution is more stable comparing to one shown in Google section and looks more like real-one. Shares movements are unstable, it is hard to find patterns in shares movements.
#
# Shares movement count distribution looks more like normal distribution that is 'sliced' from the left side (the problem is that normal distribution won't have so long tales), or cauchy distribution that will go to both directions (to the left and right), but with not so strong, tall bell shape.

# %%
smooth_microsoft_df = show_transactions_distribution_moving_average(
    microsoft_df, time_cycle='30d', plot_name="Smoothed share price over time", target_column='Price',
    x_size=5, y_size=5
    )
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(data=smooth_microsoft_df, x='datetime', y='Value', color='red').set_title(
    'smoothed shares trades capitalization over time'
    )
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(data=smooth_microsoft_df, x='datetime', y='Shares', color='green').set_title(
    'smoothed shares movements over time'
    )
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data=smooth_microsoft_df, x='Value', color='orange', bins=50).set_title(
    'smoothed shares movements over time'
    )
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data=smooth_microsoft_df, x='Shares', color='magenta', bins=50).set_title(
    'smoothed shares movements over time'
    )
plt.show()

# %% [markdown]
# ## Apple
#
# Apple share price over time has general positive trend but price is not stable, which can be explained by gaps in insiders' transactions. Shares movements show 'wave'-like pattern, where sells are happening with periodic structure that looks like waves.
#
# Count distribution for both capitalization and shares movement looks like perfect exponential distribution (like Pareto or Cauchy).

# %%
smooth_apple_df = show_transactions_distribution_moving_average(
    apple_df, time_cycle='30d', plot_name="Smoothed share price over time", target_column='Price',
    x_size=5, y_size=5
    )
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(data=smooth_apple_df, x='datetime', y='Value', color='red').set_title(
    'smoothed shares trades capitalization over time'
    )
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(data=smooth_apple_df, x='datetime', y='Shares', color='green').set_title(
    'smoothed shares movements over time'
    )
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data=smooth_apple_df, x='Value', color='orange', bins=50).set_title(
    'smoothed shares movements over time'
    )
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data=smooth_apple_df, x='Shares', color='magenta', bins=50).set_title(
    'smoothed shares movements over time'
    )
plt.show()

# %% [markdown]
# ## Amazon
#
# Amazon share price also show positive general trend and demonstrates more stable behavior comparing with other shares. Shares movements are also 'wave'-like.
#
# Count distribution by share movements and trades capitalizations look like exponential ones (Pareto or Cauchy)

# %%
smooth_amazon_df = show_transactions_distribution_moving_average(
    amazon_df, time_cycle='30d', plot_name="Smoothed share price over time", target_column='Price',
    x_size=5, y_size=5
    )
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(data=smooth_amazon_df, x='datetime', y='Value', color='red').set_title(
    'smoothed shares trades capitalization over time'
    )
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(data=smooth_amazon_df, x='datetime', y='Shares', color='green').set_title(
    'smoothed shares movements over time'
    )
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data=smooth_amazon_df, x='Value', color='orange', bins=50).set_title(
    'smoothed shares movements over time'
    )
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data=smooth_amazon_df, x='Shares', color='magenta', bins=50).set_title(
    'smoothed shares movements over time'
    )
plt.show()

# %% [markdown]
# ## Facebook
#
# Price evolution has great positive trend and shares movement comparing to the other shares is more stable and looks like real-market one.
#
# Count distribution by shares and by capitalization looks like normal one or not so strong shaped Cauchy distribution (that will go in both directions)

# %%
smooth_facebook_df = show_transactions_distribution_moving_average(
    facebook_df, time_cycle='30d', plot_name="Smoothed share price over time", target_column='Price',
    x_size=5, y_size=5
    )
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(data=smooth_facebook_df, x='datetime', y='Value', color='red').set_title(
    'smoothed shares trades capitalization over time'
    )
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(data=smooth_facebook_df, x='datetime', y='Shares', color='green').set_title(
    'smoothed shares movements over time'
    )
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data=smooth_facebook_df, x='Value', color='orange', bins=50).set_title(
    'smoothed shares movements over time'
    )
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data=smooth_facebook_df, x='Shares', color='magenta', bins=50).set_title(
    'smoothed shares movements over time'
    )
plt.show()

# %% [markdown]
# ## Netflix
#
# Price evolution is stable and has positive trend and distribution is stable with one big deviation in the beginning of 2021.
#
# Count distribution by shares and capitalization looks like exponential one (Pareto or Cauchy)

# %%
smooth_netflix_df = show_transactions_distribution_moving_average(
    netflix_df, time_cycle='30d', plot_name="Smoothed share price over time", target_column='Price',
    x_size=5, y_size=5
    )
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(data=smooth_netflix_df, x='datetime', y='Value', color='red').set_title(
    'smoothed shares trades capitalization over time'
    )
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(data=smooth_netflix_df, x='datetime', y='Shares', color='green').set_title(
    'smoothed shares movements over time'
    )
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data=smooth_netflix_df, x='Value', color='orange', bins=50).set_title(
    'smoothed shares movements over time'
    )
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data=smooth_netflix_df, x='Shares', color='magenta', bins=50).set_title(
    'smoothed shares movements over time'
    )
plt.show()

# %% [markdown]
# ## Tesla
#
# Tesla shares price is the only one with negative trend and great drop in the end of 2020. Shares movements are 'wave'-like.
#
# Count distribution by capitalization and shares has no clear pattern. Neither exponential one (great rise after one bell-shape strong rise), nor normal one due to drop between bells.

# %%
smooth_tesla_df = show_transactions_distribution_moving_average(
    tesla_df, time_cycle='30d', plot_name="Smoothed share price over time", target_column='Price',
    x_size=5, y_size=5
    )
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(data=smooth_tesla_df, x='datetime', y='Value', color='red').set_title(
    'smoothed shares trades capitalization over time'
    )
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(data=smooth_tesla_df, x='datetime', y='Shares', color='green').set_title(
    'smoothed shares movements over time'
    )
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data=smooth_tesla_df, x='Value', color='orange', bins=50).set_title(
    'smoothed shares movements over time'
    )
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data=smooth_tesla_df, x='Shares', color='magenta', bins=50).set_title(
    'smoothed shares movements over time'
    )
plt.show()
