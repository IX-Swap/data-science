# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('dark_background')

# %%
user_data_df = pd.read_csv('traders_detailed_info.csv')
user_data_df.drop(columns=['Unnamed: 0'], inplace=True)
user_data_df
# Out:
#             amm                                      trader      total_pnl  \
# 0      BTC/USDC  0x1a48776f436bcdaa16845a378666cf4ba131eb0f -496466.874971
# 1      BTC/USDC  0x9602686bf53a17baed60c48ba34ed4219a532381      17.792407
# 2      BTC/USDC  0x43bd90e4cc93d6e40580507102cc7b1bc8a25284       1.235316
# 3      BTC/USDC  0x5bea7caa02142ba59885466757e1112819731f09    -164.847399
# 4      BTC/USDC  0x069a67b8f965d02d095be12ae55e31e769692df4      99.507222
# ...         ...                                         ...            ...
# 18240  FTT/USDC  0xc0f872a7127bdc6d98af04899d1a1d22376c7b6b     -10.949403
# 18241  FTT/USDC  0x419df1d41f84de3d3854a4e6d0b4d772ebd1b13b       0.230596
# 18242  FTT/USDC  0xb39885f302643a5f96f743c3621d628dc3f72ce6     -46.505655
# 18243  FTT/USDC  0xa84daa76815f6d2cf99e406bd693e8588bc36dbe       0.000000
# 18244  FTT/USDC  0xfe8b307829c386bc056e43fa2f4a9edc7a7a62ca       0.000000
#
# ...

# %%
user_data_df.describe().T
# Out:
#                                      count          mean           std  \
# total_pnl                          18245.0   1606.567193  75086.832511
# max_found_margin                   18245.0   9924.861598  70644.851277
# median_margin                      18245.0   3479.434989  25105.411259
# max_found_position_notional        18245.0   8465.774472  24567.063851
# median_position_notional           18245.0   3008.650731   7458.974371
# min_found_position_notional        18245.0   1548.427085   5188.332807
# max_found_exchanged_position_size  18245.0    971.698485   5169.709537
# median_exchanged_position_size     18245.0      8.624145    717.423592
# min_found_exchanged_position_size  18245.0   -989.232447   5016.480310
# operations_count                   18245.0  25375.297890  29102.026555
# time_window_seconds                18245.0      0.000000      0.000000
#
#                                             min         25%           50%  \
# ...

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(user_data_df.corr(), annot=True)
plt.show()

# %%
fig = plt.figure(figsize=(14, 14))

index = 1
for column in ["max_found_margin", "median_margin",
              "max_found_position_notional", "median_position_notional", "min_found_position_notional",
              "max_found_exchanged_position_size", "median_exchanged_position_size", "min_found_exchanged_position_size",
              "operations_count"]:
    ax = plt.subplot(3, 3, index)
    ax.hist(user_data_df[column], bins=100)
    ax.set_xlabel(column)
    ax.set_ylabel("Count of records")
    ax.set_title("Values distribution for " + column)
    ax.grid(True, linestyle='--')
    index += 1
    
fig.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(14, 14))

index = 1
for column in ["max_found_margin", "median_margin",
              "max_found_position_notional", "median_position_notional", "min_found_position_notional",
              "max_found_exchanged_position_size", "median_exchanged_position_size", "min_found_exchanged_position_size",
              "operations_count"]:
    ax = plt.subplot(3, 3, index)
    ax.hist(user_data_df[user_data_df['total_pnl'] > 0][column], bins=100)
    ax.set_xlabel(column)
    ax.set_ylabel("Count of records")
    ax.set_title("Values distribution for " + column)
    ax.grid(True, linestyle='--')
    index += 1
    
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.hist(user_data_df["total_pnl"], bins=100)
ax.set_xlabel("profit and loss")
ax.set_ylabel("records count")
ax.set_title("distribution of profit and loss")
ax.grid(True, linestyle='--')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.hist(user_data_df[user_data_df['total_pnl'] > 1000]["total_pnl"], bins=100)
ax.set_xlabel("profit and loss")
ax.set_ylabel("records count")
ax.set_title("distribution of profit and loss (only bigger than 1000 USD profit)")
ax.grid(True, linestyle='--')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.hist(user_data_df[user_data_df['total_pnl'] < -1000]["total_pnl"], bins=100)
ax.set_xlabel("profit and loss")
ax.set_ylabel("records count")
ax.set_title("distribution of profit and loss (only losses bigger than 1000 USD)")
ax.grid(True, linestyle='--')
plt.show()

# %%
print("there are " + str(len(user_data_df[user_data_df['total_pnl'] > 0])) + " traders who exctracted profit" + 
     " and " + str(len(user_data_df[user_data_df['total_pnl'] < 0])) + " who had losses and total collected " +
     "profit is " + str(user_data_df[user_data_df['total_pnl'] > 0]['total_pnl'].sum()) + ' while total losses ' +  
     'are equal to ' + str(user_data_df[user_data_df['total_pnl'] < 0]['total_pnl'].sum()) + ' and therefore' + 
     ' overall balance is equal to ' + str(user_data_df['total_pnl'].sum()))
# Out:
# there are 6501 traders who exctracted profit and 9866 who had losses and total collected profit is 81341726.06051086 while total losses are equal to -52029907.62576955 and therefore overall balance is equal to 29311818.4347413

# %% [markdown]
# # Time segment

# %%
time_position_changes_df = pd.read_csv("opens_closes_with_time.csv")
time_position_changes_df
# Out:
#          Unnamed: 0                                                 id  \
# 0                 0  0x06d54c4ad4bfff493051ef548557f4fa0c76fb2dd678...
# 1                 1  0xe9d804889de5a27a356777a588d6c018e55fa1cae61c...
# 2                 2  0xea81e16520eae51395b4627365487daa2013df876ef3...
# 3                 3  0xcbc30cda2cff5814702d67c67530f6598a670ad990f3...
# 4                 4  0xb7f635c0407feb60d7386e18b0d102503e5c9f034be9...
# ...             ...                                                ...
# 9341945     9341945  0x46558498bb5962a524f0b63d724d92777bb17b504e44...
# 9341946     9341946  0x3ddf503cacc2125a68cc17a9b84e2971d6242423eea0...
# 9341947     9341947  0x4215d5f56936f1604171ada50922c0e5af609369ea10...
# 9341948     9341948  0x507dae82675d33cc29766b5792ef6c527149ac4ddae4...
# 9341949     9341949  0x356f026e86fdf1f0a01f8bea613c0440cd5604cc1f51...
#
#                                              trader  \
# 0        0x1a48776f436bcdaa16845a378666cf4ba131eb0f
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.hist(time_position_changes_df['seconds_passed_from_any_last_action'], bins=100)
ax.set_xlabel("seconds passed from the last trader action on platform")
ax.set_ylabel("count of records")
ax.set_title("Distribution of time passed from the last performed action by trader")
ax.grid(True, linestyle='--')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.hist(time_position_changes_df[time_position_changes_df['seconds_passed_from_any_last_action'] < 1000]['seconds_passed_from_any_last_action'], bins=100)
ax.set_xlabel("seconds passed from the last trader action on platform")
ax.set_ylabel("count of records")
ax.set_title("Distribution of time passed from the last performed action by trader (less than 1000 seconds)")
ax.grid(True, linestyle='--')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.hist(time_position_changes_df[time_position_changes_df['seconds_passed_from_any_last_action'] < 60]['seconds_passed_from_any_last_action'], bins=100)
ax.set_xlabel("seconds passed from the last trader action on platform")
ax.set_ylabel("count of records")
ax.set_title("Distribution of time passed from the last performed action by trader (less than minute)")
ax.grid(True, linestyle='--')
plt.show()

# %%
time_position_changes_df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-9d9eeaa6e701> in <module>
# ----> 1 time_position_changes_df
#
# D:\programs\anaconda\lib\site-packages\IPython\core\displayhook.py in __call__(self, result)
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
# --> 262             format_dict, md_dict = self.compute_format_data(result)
#     263             self.update_user_ns(result)
#     264             self.fill_exec_result(result)
#
# D:\programs\anaconda\lib\site-packages\IPython\core\displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# ...
