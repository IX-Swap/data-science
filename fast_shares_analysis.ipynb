# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
def show_value_price_timeseries(
    df: pd.DataFrame, 
    plot_name: str, price_instead_value: bool,
    x_size: int=15, y_size: int=9
):
    # set size and set timeseries representation with automatic definition
    fig, ax = plt.subplots(figsize=(x_size, y_size))
    fig.autofmt_xdate()

    if price_instead_value:
        ax.plot_date(df.datetime, df.Price, linestyle='solid', marker=None, color='red', label=str("Share price"))
    else:
        ax.plot_date(df.datetime, df.Value, linestyle='solid', marker=None, label=str("Trades value"))

    # set labels
    ax.set_xlabel("Time")
    ax.set_ylabel("Price and value")

    # set title and legend
    fig.suptitle(plot_name)
    fig.legend()

# %%
google_df = pd.read_csv(os.getcwd() + '\GOOG.csv')
microsoft_df = pd.read_csv(os.getcwd() + '\MSFT.csv')
apple_df = pd.read_csv(os.getcwd() + '\AAPL.csv')
amazon_df = pd.read_csv(os.getcwd() + '\AMZN.csv')
facebook_df = pd.read_csv(os.getcwd() + '\FB.csv')
netflix_df = pd.read_csv(os.getcwd() + '\\NFLX.csv')
tesla_df = pd.read_csv(os.getcwd() + '\TSLA.csv')

# %%
google_df
# Out:
#      Unnamed: 0               Insider      Type     Value          Date  \
# 0             0         PICHAI SUNDAR    Direct   8090303  Sep 15, 2021
# 1             1           BRIN SERGEY    Direct  40307198  Sep 09, 2021
# 2             2           BRIN SERGEY    Direct  40240838  Sep 08, 2021
# 3             3       HENNESSY JOHN L  Indirect    299520  Sep 07, 2021
# 4             4           BRIN SERGEY    Direct  40390311  Sep 07, 2021
# ..          ...                   ...       ...       ...           ...
# 145         145       HENNESSY JOHN L  Indirect     51806  Apr 06, 2020
# 146         146  O TOOLE AMIE THUENER    Direct     66994  Apr 02, 2020
# 147         147            MATHER ANN    Direct     38120  Apr 01, 2020
# 148         148          PORAT RUTH M    Direct         0  Mar 25, 2020
# 149         149         PICHAI SUNDAR    Direct         0  Mar 25, 2020
#
#      Shares        Price                                        Info
# ...

# %%
plt.figure(figsize=(20, 20))

plt.subplot(3, 3, 1)
sns.histplot(data=google_df, x='Value', color='green').set_title('Operations values for Google shares (in USD)')

plt.subplot(3, 3, 2)
sns.histplot(data=microsoft_df, x='Value', color='blue').set_title('Operations values for Microsoft shares (in USD)')

plt.subplot(3, 3, 3)
sns.histplot(data=apple_df, x='Value', color='gray').set_title('Operations values for Apple shares (in USD)')

plt.subplot(3, 3, 4)
sns.histplot(data=amazon_df, x='Value', color='yellow').set_title('Operations values for Amazon shares (in USD)')

plt.subplot(3, 3, 5)
sns.histplot(data=facebook_df, x='Value', color='magenta').set_title('Operations values for Facebook shares (in USD)')

plt.subplot(3, 3, 6)
sns.histplot(data=netflix_df, x='Value', color='red').set_title('Operations values for Netflix shares (in USD)')

plt.subplot(3, 3, 7)
sns.histplot(data=tesla_df, x='Value', color='gray').set_title('Operations values for Tesla shares (in USD)')

plt.subplots_adjust(wspace=0.2, hspace=0.2)

plt.show()

# %%
google_df['datetime'] = pd.to_datetime(google_df['Date'], format="%b %d, %Y")
microsoft_df['datetime'] = pd.to_datetime(microsoft_df['Date'], format="%b %d, %Y")
apple_df['datetime'] = pd.to_datetime(apple_df['Date'], format="%b %d, %Y")
amazon_df['datetime'] = pd.to_datetime(amazon_df['Date'], format="%b %d, %Y")
facebook_df['datetime'] = pd.to_datetime(facebook_df['Date'], format="%b %d, %Y")
netflix_df['datetime'] = pd.to_datetime(netflix_df['Date'], format="%b %d, %Y")
tesla_df['datetime'] = pd.to_datetime(tesla_df['Date'], format="%b %d, %Y")

# %% [markdown]
# # Showing distribution of shares sales and their price

# %%
plt.figure(figsize=(20, 50))

plt.subplot(7, 2, 1)
sns.lineplot(x='datetime', y='Value', data=google_df, color='green').set_title("Google shares sales values through time (in USD)")
plt.subplot(7, 2, 2)
sns.lineplot(x='datetime', y='Price', data=google_df, color="orange").set_title("Google shares price through time (in USD)")

plt.subplot(7, 2, 3)
sns.lineplot(x='datetime', y='Value', data=microsoft_df, color='blue').set_title("Microsoft shares sales values through time (in USD)")
plt.subplot(7, 2, 4)
sns.lineplot(x='datetime', y='Price', data=microsoft_df, color="orange").set_title("Microsoft shares price through time (in USD)")

plt.subplot(7, 2, 5)
sns.lineplot(x='datetime', y='Value', data=apple_df, color='gray').set_title("Apple shares sales values through time (in USD)")
plt.subplot(7, 2, 6)
sns.lineplot(x='datetime', y='Price', data=apple_df, color="orange").set_title("Apple shares price through time (in USD)")

plt.subplot(7, 2, 7)
sns.lineplot(x='datetime', y='Value', data=amazon_df, color='yellow').set_title("Amazon shares sales values through time (in USD)")
plt.subplot(7, 2, 8)
sns.lineplot(x='datetime', y='Price', data=amazon_df, color="orange").set_title("Amazon shares price through time (in USD)")

plt.subplot(7, 2, 9)
sns.lineplot(x='datetime', y='Value', data=facebook_df, color='magenta').set_title("Facebook shares sales values through time (in USD)")
plt.subplot(7, 2, 10)
sns.lineplot(x='datetime', y='Price', data=facebook_df, color="orange").set_title("Facebook shares price through time (in USD)")

plt.subplot(7, 2, 11)
sns.lineplot(x='datetime', y='Value', data=netflix_df, color='red').set_title("Netflix shares sales values through time (in USD)")
plt.subplot(7, 2, 12)
sns.lineplot(x='datetime', y='Price', data=netflix_df, color="orange").set_title("Netflix shares price through time (in USD)")

plt.subplot(7, 2, 13)
sns.lineplot(x='datetime', y='Value', data=tesla_df, color='gray').set_title("Tesla shares sales values through time (in USD)")
plt.subplot(7, 2, 14)
sns.lineplot(x='datetime', y='Price', data=tesla_df, color="orange").set_title("Tesla shares price through time (in USD)")

plt.show()

# %%
plt.figure(figsize=(20, 20))

plt.subplot(3, 3, 1)
sns.histplot(data=google_df, x='Shares', color='green').set_title('Google shares transaction amount and their frequency')

plt.subplot(3, 3, 2)
sns.histplot(data=microsoft_df, x='Shares', color='blue').set_title('Microsoft shares transaction amount and their frequency')

plt.subplot(3, 3, 3)
sns.histplot(data=apple_df, x='Shares', color='gray').set_title('Apple shares transaction amount and their frequency')

plt.subplot(3, 3, 4)
sns.histplot(data=amazon_df, x='Shares', color='yellow').set_title('Amazon shares transaction amount and their frequency')

plt.subplot(3, 3, 5)
sns.histplot(data=facebook_df, x='Shares', color='magenta').set_title('Facebook shares transaction amount and their frequency')

plt.subplot(3, 3, 6)
sns.histplot(data=netflix_df, x='Shares', color='red').set_title('Netflix shares transaction amount and their frequency')

plt.subplot(3, 3, 7)
sns.histplot(data=tesla_df, x='Shares', color='gray').set_title('Tesla shares transaction amount and their frequency')

plt.subplots_adjust(wspace=0.2, hspace=0.2)

plt.show()

# %%
plt.figure(figsize=(20, 50))

plt.subplot(7, 2, 1)
sns.lineplot(x='datetime', y='Shares', data=google_df, color='green').set_title("Google shares operations amount through time")
plt.subplot(7, 2, 2)
sns.lineplot(x='datetime', y='Price', data=google_df, color="orange").set_title("Google shares price through time (in USD)")

plt.subplot(7, 2, 3)
sns.lineplot(x='datetime', y='Shares', data=microsoft_df, color='blue').set_title("Microsoft shares operations amount through time")
plt.subplot(7, 2, 4)
sns.lineplot(x='datetime', y='Price', data=microsoft_df, color="orange").set_title("Microsoft shares price through time (in USD)")

plt.subplot(7, 2, 5)
sns.lineplot(x='datetime', y='Shares', data=apple_df, color='gray').set_title("Apple shares operations amount through time")
plt.subplot(7, 2, 6)
sns.lineplot(x='datetime', y='Price', data=apple_df, color="orange").set_title("Apple shares price through time (in USD)")

plt.subplot(7, 2, 7)
sns.lineplot(x='datetime', y='Shares', data=amazon_df, color='yellow').set_title("Amazon shares operations amount through time")
plt.subplot(7, 2, 8)
sns.lineplot(x='datetime', y='Price', data=amazon_df, color="orange").set_title("Amazon shares price through time (in USD)")

plt.subplot(7, 2, 9)
sns.lineplot(x='datetime', y='Shares', data=facebook_df, color='magenta').set_title("Facebook shares operations amount through time")
plt.subplot(7, 2, 10)
sns.lineplot(x='datetime', y='Price', data=facebook_df, color="orange").set_title("Facebook shares price through time (in USD)")

plt.subplot(7, 2, 11)
sns.lineplot(x='datetime', y='Shares', data=netflix_df, color='red').set_title("Netflix shares operations amount through time")
plt.subplot(7, 2, 12)
sns.lineplot(x='datetime', y='Price', data=netflix_df, color="orange").set_title("Netflix shares price through time (in USD)")

plt.subplot(7, 2, 13)
sns.lineplot(x='datetime', y='Shares', data=tesla_df, color='gray').set_title("Tesla shares operations amount through time")
plt.subplot(7, 2, 14)
sns.lineplot(x='datetime', y='Price', data=tesla_df, color="orange").set_title("Tesla shares price through time (in USD)")

plt.show()

# %%
# generating cauchy distribution
from scipy.stats import cauchy
cauchy = cauchy.rvs(size=1312, loc=0, scale=1700)

# generating pareto distribution
pareto = np.random.pareto(0.258, size=1700)

plt.figure(figsize=(10, 10))
plt.subplots_adjust(wspace=0.1, hspace=0.25)

plt.subplot(3, 1, 1)
sns.histplot(x=cauchy, color='green', binrange=[0, 300000], bins=100).set_title('Cauchy distribution')

plt.subplot(3, 1, 2)
sns.histplot(x=pareto, color='blue', binrange=[0, 300000], bins=100).set_title('Pareto distribution')

plt.subplot(3, 1, 3)
sns.histplot(data=apple_df, x='Shares', color='gray').set_title('Apple shares transaction amount and their frequency')

plt.show()
